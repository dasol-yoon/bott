# %%
import torch

# %%
res_EI = torch.load("/home/pb482/bott/results/GT_230.0_7.0_-3.0/EI/trial_1.pt",map_location=torch.device('cpu'))

# %%
res_EICF = torch.load("/home/pb482/bott/results/GT_230.0_7.0_-3.0/EICF/trial_1.pt",map_location=torch.device('cpu'))

# %%
res = torch.load("/home/pb482/bott/results/GT_230.0_7.0_-3.0/KG/trial_23.pt",map_location=torch.device('cpu'))

# %%
X = res["train_X"]
train_Y = res["train_Y"]
acqf_vals = res['acqf_val_list']
acqf_runtime = res['acqf_runtime']
gp_runtime = res['gp_runtime']
physics_model_runtime = res['physics_model_runtime']
obj = res['obj_func_val']
pixelLoss=res['pixelLoss']
best_val = obj.max()
n_init_evals = X.shape[0]

# %%
res['pixelLoss']
# Out:
# tensor([[0.1311],
#         [0.0360],
#         [0.0443],
#         [0.0237],
#         [0.0512],
#         [0.0091],
#         [0.0154],
#         [0.0221],
#         [0.0095],
#         [0.0125],
#         [0.1317],
#         [0.0871],
#         [0.0899],
#         [0.0490],
#         [0.1771],
#         [0.0330],
#         [0.1208],
#         [0.1012],
#         [0.1371],
#         [0.0576],
#         [0.0328],
#         [0.1387],
#         [0.0356],
#         [0.1046],
#         [0.0196],
#         [0.1604],
#         [0.0415],
#         [0.0732],
#         [0.2010],
#         [0.0962],
#         [0.0571],
#         [0.0246],
#         [0.1840],
#         [0.0769],
#         [0.2014],
#         [0.0907],
#         [0.0248],
#         [0.1306],
#         [0.0091]], dtype=torch.float64)

# %%
res_EI['obj_func_val']
# Out:
# tensor([[-0.0836],
#         [-0.1026],
#         [-0.1026],
#         [-0.0804],
#         [-0.1017],
#         [-0.0600],
#         [-0.0553],
#         [-0.0679],
#         [-0.0510],
#         [-0.0597],
#         [-0.0408],
#         [-0.0358],
#         [-0.0474],
#         [-0.0291],
#         [-0.0341],
#         [-0.0282],
#         [-0.0261],
#         [-0.0280],
#         [-0.0538],
#         [-0.0229],
#         [-0.0237],
#         [-0.0192],
#         [-0.0138],
#         [-0.0292],
#         [-0.0132],
#         [-0.0111],
#         [-0.1197],
#         [-0.0126],
#         [-0.1209],
#         [-0.0088],
#         [-0.0077],
#         [-0.0665],
#         [-0.0089],
#         [-0.0073],
#         [-0.0072],
#         [-0.0068],
#         [-0.0079],
#         [-0.0912],
#         [-0.0061],
#         [-0.0059],
#         [-0.0050],
#         [-0.0189],
#         [-0.0051],
#         [-0.1606],
#         [-0.2346],
#         [-0.1609],
#         [-0.0920],
# ...
